# %% [markdown]
# # 02_preprocess_feature
# Tiền xử lý và feature engineering

# %%
import sys, os, yaml
sys.path.append(os.path.abspath(os.path.join('..')))

from src.data.loader import load_data, add_time_features
from src.data.cleaner import preprocess_pipeline
from src.features.builder import scale_features

# %%
# 1. Load Config & Data
with open('../configs/params.yaml', 'r', encoding='utf-8') as f:
    config = yaml.safe_load(f)

df = load_data(f"../{config['raw_data_path']}")
df = add_time_features(df)

# %%
# 2. Thực hiện làm sạch & Rời rạc hóa
df_cleaned = preprocess_pipeline(df, config)

# %%
# 3. Chuẩn hóa để phục vụ Phân cụm (Clustering)
numerical_cols = ['Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Pressure (millibars)']
df_final = df_cleaned
#df_final, scaler = scale_features(df_cleaned, numerical_cols)

# %%
# 4. Lưu dữ liệu đã xử lý
df_final.to_csv(f"../{config['processed_data_path']}", index=False)

print("Tiền xử lý hoàn tất! Dữ liệu đã sẵn sàng cho Mining & Modeling.")
display(df_final[['Temp_Class', 'Humidity_Class', 'Pressure (millibars)']].head())
# Out:
# Tiền xử lý hoàn tất! Dữ liệu đã sẵn sàng cho Mining & Modeling.
#   Temp_Class Humidity_Class  Pressure (millibars)
# 0       Cold            Wet               1015.13
# 1       Cold            Wet               1015.63
# 2       Cold            Wet               1015.94
# 3       Cold            Wet               1016.41
# 4       Cold            Wet               1016.51
